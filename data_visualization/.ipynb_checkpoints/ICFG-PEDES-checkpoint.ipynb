# %% [markdown]
# # Introduction to dataset

# %% [markdown]
# ...

# %% [markdown]
# # Demo in notebook

# %% [markdown]
# ## Set up

# %%
import numpy as np; import pandas as pd
from pathlib import Path
import os, sys, time, random, math, cv2, PIL, json
import matplotlib.pyplot as plt; import seaborn as sns
print(os.getcwd())
# Out:
# /home/jovyan/workspace/BA-PRE_THESIS/REPORT/data_visualization

# %%
ROOT_PATH = Path('../../DATASET/ICFG-PEDES')
ROOT_IMG = ROOT_PATH/'imgs'
caption_path = os.path.join(ROOT_PATH, "ICFG-PEDES.json")
caption_df = pd.read_json(caption_path)
caption_df.head(1)
# Out:
#    split                                       file_path  id  \
# 0  train  test/0627/0627_010_05_0303afternoon_1591_0.jpg   0
#
#                                     processed_tokens  \
# 0  [[A, young, age, woman, has, black, shoulder-l...
#
#                                             captions
# 0  [A young age woman has black shoulder-length h...

# %% [markdown]
# __Split captions array into 2 caption__

# %%
filepath_convert = lambda x: os.path.join(ROOT_IMG, x)
caption_df["file_path"] = caption_df["file_path"].apply(filepath_convert)
caption_df.rename(columns={"file_path": "image"}, inplace=True)
caption_df.set_index("id", inplace=True)
caption_df.drop(columns=["processed_tokens"], inplace=True)
caption_df.head(1)
# Out:
#     split                                              image  \
# id
# 0   train  ../../DATASET/ICFG-PEDES/imgs/test/0627/0627_0...
#
#                                              captions
# id
# 0   [A young age woman has black shoulder-length h...

# %% [markdown]
# ## View dataset

# %%
from IPython.core.display import HTML

# %%
def to_img_tag(path):
    return '<img src="' + path + '" width="368" height="768" >'

display(HTML(caption_df.head(70).to_html(escape=False, formatters=dict(image=to_img_tag))))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>split</th>
#       <th>image</th>
#       <th>captions</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>train</td>
#       <td><img src="../../DATASET/ICFG-PEDES/imgs/test/0627/0627_010_05_0303afternoon_1591_0.jpg" width="368" height="768" ></td>
#       <td>[A young age woman has black shoulder-length hair and her is wearing a long grey collar jacket with white rounded neck inside with black pants and black shoes.]</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>train</td>
#       <td><img src="../../DATASET/ICFG-PEDES/imgs/test/0627/0627_012_05_0303afternoon_1592_3.jpg" width="368" height="768" ></td>
#       <td>[A young woman with straight black long hair is wearing a white turtle-neck sweater, a long grey coat with fur on the collar, black fitted pants, and black boots.]</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>train</td>
#       <td><img src="../../DATASET/ICFG-PEDES/imgs/test/0627/0627_008_05_0303afternoon_1589_5.jpg" width="368" height="768" ></td>
#       <td>[A tall, thin girl in her mid 20's with shoulder-length, fringed, straight, black hair is wearing a grey-colored long overcoat paired with black colored skinny jeggings and a white-colored high neck inner. She is also wearing a pair of black ankle-length boots.]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>train</td>
#       <td><img src="../../DATASET/ICFG-PEDES/imgs/test/2868/2868_005_05_0114afternoon_0833_1_ex.jpg" width="368" height="768" ></td>
#       <td>[A young woman with her head covered in a white wool beanie with grey pom-pom strings. She is wearing a sea green winter coat over a pink scarf. She is also wearing black jeans and black Oxfords shoes with black soles and holding black bag.]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>train</td>
#       <td><img src="../../DATASET/ICFG-PEDES/imgs/test/2868/2868_010_01_0114afternoon_0888_1.jpg" width="368" height="768" ></td>
#       <td>[A teenage girl with straight shoulder length black hair is wearing a white beanie with gray fur and blue hooded insulated down coat with black pants and black shoes with grey soles. She is wearing a gray backpack and holding black something in her hands.]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>train</td>
#       <td><img src="../../DATASET/ICFG-PEDES/imgs/test/2868/2868_013_01_0114afternoon_0889_0_ex.jpg" width="368" height="768" ></td>
#       <td>[A girl is wearing a white beanie with long pompoms and a sea-green down coat. She is also wearing a pair of fitted black pants and carrying an off-white backpack.]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td