# %% [markdown]
# # Introduction to dataset

# %% [markdown]
# # Demo in notebook

# %% [markdown]
# ## Set up

# %%
import numpy as np; import pandas as pd
from pathlib import Path
import os, sys, time, random, math, cv2, PIL, json
import matplotlib.pyplot as plt; import seaborn as sns
print(os.getcwd())
# Out:
# /home/jovyan/workspace/BA-PRE_THESIS/REPORT/data_visualization

# %%
ROOT_PATH = Path('../../DATASET/RSTPReid')
ROOT_IMG = ROOT_PATH/'imgs'
caption_path = os.path.join(ROOT_PATH, "data_captions.json")
caption_df = pd.read_json(caption_path)
caption_df.head(3)
# Out:
#    id           img_path                                           captions  \
# 0   0  0000_c14_0031.jpg  [The man is wearing a grey jacket and a blue s...
# 1   0  0000_c14_0032.jpg  [He is wearing a grey jacket with a blue shirt...
# 2   0   0000_c1_0004.jpg  [This is a man wearing a grey jacket.He is wal...
#
#    split
# 0  train
# 1  train
# 2  train

# %% [markdown]
# __Split captions array into 2 caption__

# %%
caption_extract_0 = lambda x: x[0]
caption_extract_1 = lambda x: x[1]
filepath_convert = lambda x: os.path.join(ROOT_IMG, x)
caption_df["caption_0"] = caption_df["captions"].apply(caption_extract_0)
caption_df["caption_1"] = caption_df["captions"].apply(caption_extract_1)
caption_df["img_path"] = caption_df["img_path"].apply(filepath_convert)
caption_df.rename(columns={"img_path": "image"}, inplace=True)
caption_df.drop(columns=["captions"], inplace=True)
caption_df.set_index("id", inplace=True)

# %% [markdown]
# ## View dataset

# %%
from IPython.core.display import HTML
def to_img_tag(path):
    return '<img src="' + path + '" width="184" height="384" >'

display(HTML(caption_df.head(70).to_html(escape=False, formatters=dict(image=to_img_tag))))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>image</th>
#       <th>split</th>
#       <th>caption_0</th>
#       <th>caption_1</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0000_c14_0031.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man is wearing a grey jacket and a blue shirt.His trousers are black and his shoes are brown.He is walking.</td>
#       <td>The man is a strong man who is in a grey jacket.His shirt is blue and his trousers is black.</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0000_c14_0032.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>He is wearing a grey jacket with a blue shirt inside.He put his hands in his pockets.He is wearing a pair of glasses.He is carrying a black bag.</td>
#       <td>The man with glasses is wearing a grey jacket with a blue shirt inside. He has his hands in his pockets.</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0000_c1_0004.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>This is a man wearing a grey jacket.He is walking with his hands in his pockets.His trousers are black.His shoes are brown.</td>
#       <td>The man is walking.He is wearing a dark grey jacket that is close.His trousers is black.He has a pair of brown shoes.</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0000_c5_0022.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man is walking with a black bag.He wears a bright jacket and a pair of black trousers.His shoes is dark tanned.</td>
#       <td>A man with black hair, wearing glasses, a gray and black shirt, black pants and black shoes, carrying a black backpack, is walking, a hand in the pocket</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0000_c7_0015.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man is walking.He is wearing a grey jacket and black trousers.His shoes are brown and his bag is black.He is looking around.</td>
#       <td>The man is walking while carrying a black backpack.His dark trousers are a bit tight.He has black short hair.His shoes are dark brown.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0001_c14_0033.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man is wearing a black coat and dark blue trousers. He walked with a black bag on his back.</td>
#       <td>A man with black hair, wearing glasses, a gray and black shirt, black pants and black shoes, carrying a black backpack, is walking, a hand in the pocket</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0001_c1_0003.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>A man in a black jacket, dark trousers and a bag is walking with a plastic bag in his hand, looking at his mobile phone.</td>
#       <td>The man is walking.He is wearing a black overcoat and black trousers.He is carrying a bag.He is looking at his left hand with a pocket.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0001_c1_0014.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>A man with black hair, wearing glasses, a gray and black shirt, black pants and black shoes, carrying a black backpack, is walking, a hand in the pocket</td>
#       <td>The man is walking with a pocket in his hand.He is wearing a pair of glasses.He is wearing a black jacket and grey trousers.His shirt is blue and shoes are brown.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0001_c5_0025.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man with glasses is wearing a dark jacket，grey trousers and brown shoes. He is walking with a bag on his back and a plastic bag in his hand.</td>
#       <td>The man is wearing a tight black jacket and light grey trousers.A clear plastic bag is in his hand, and a black satchel slung over his shoulder.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0001_c7_0018.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man is walking with a pocket in his hand. He is wearing a black jacket and grey trousers. His shoes are brown. He is wearing a pair of glasses and looking around.</td>
#       <td>A man with black hair, wearing glasses, a gray and black shirt, black pants and black shoes, carrying a black backpack, is walking, a hand in the pocket</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0002_c14_0024.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>A man with black hair, wearing glasses, a gray and black shirt, black pants and black shoes, carrying a black backpack, is walking, a hand in the pocket</td>
#       <td>A woman with long hair is wearing a black coat, dark blue jeans and grey sneakers. She walked with her hands in her pockets.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0002_c15_0027.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>A girl with long hair was wearing a black jacket with a white shirt and dark trousers. She was walking with her bag slung and her hand in her pocket.</td>
#       <td>The person is a women.She has a white lining in her short black leather coat.She had a black satchel slung over her back.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0002_c1_0003.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>A man with black hair, wearing glasses, a gray and black shirt, black pants and black shoes, carrying a black backpack, is walking, a hand in the pocket</td>
#       <td>The woman who has long hair is walking.She wears a short black jacket that is open and a white t-shirt in it.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0002_c5_0020.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The woman has brown-long hair.She wears a black tight jacket and a pair of navy-blue jeans.Her shoes are white.She has a black shoulder bag.</td>
#       <td>A woman with long brown hair was wearing a black coat with a white shirt, dark blue jeans and white sports shoes. She was walking with her bag slung and her hand in her pocket.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0002_c7_0013.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>A woman with brown hair was wearing a black jacket with a white shirt inside, dark blue jeans and grey sneakers. She was walking with her bag slung and her hand in her pocket.</td>
#       <td>The woman has long brown hair. She is wearing a black feather jacket , blue jeans and white shoes with a white shirt under her jacket.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0003_c14_0027.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man with glasses is wearing a black down jacket, trousers and shoes. As he walked, he copied his left hand into his pocket.</td>
#       <td>A man with black hair, wearing glasses, a gray and black shirt, black pants and black shoes, carrying a black backpack, is walking, a hand in the pocket</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="../../DATASET/RSTPReid/imgs/0003_c15_0031.jpg" width="184" height="384" ></td>
#       <td>train</td>
#       <td>The man has black hair and he is walking. He is wearing a pair of glasses and carrying a black bag.He is wearing a black down-filled coat and black trousers.</td>
#       <
